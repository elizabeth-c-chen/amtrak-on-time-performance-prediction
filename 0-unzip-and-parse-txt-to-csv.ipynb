# %%
import pandas as pd
import os
import sys
import zipfile
import re
from io import StringIO

# %%
northbound = [[66, 82, 86, 88, 94, 132, 176, 178, 190, 194, 150, 160, 162, 164, 166, 168, 170, 172, 174]]
southbound = [[67, 93, 95, 99, 135, 169, 177, 137, 139, 161, 163, 165, 167, 171, 173, 175, 195]]

all_trains = sorted(northbound[0] + southbound[0])

# %%
years = [year for year in range(2011, 2024+1)]
print(years)
# Out:
# [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %% [markdown]
# ## Function to parse train data text file

# %%
def parse_train_file(input_file):
    """
    Parse individual train .txt file from https://dixielandsoftware.net/Amtrak/status/StatusPages/index.html archives
    """ 
    # CSV column headers
    headers = [
        'Station Code',
        'Schedule Arrival Day',
        'Schedule Arrival Time',
        'Schedule Departure Day',
        'Schedule Departure Time',
        'Actual Arrival Time',
        'Actual Departure Time',
        'Comments'
    ]
    
    parsed_data = [] # Store parsed rows
    
    try:
        # Read the file line by line.
        with open(input_file, 'r') as data_file:
            for line in data_file.readlines():
                # We are only interested in lines that start with '*' and a 3-letter station code.
                # We ignore the header and comment lines.
                if re.match(r'\* [A-Z]{3}', line):
                     # Remove the leading '*' and space from the line.
                    line = line.lstrip('* ')
                    
                    # Clean up the line to handle inconsistent spacing
                    clean_line = re.sub(r'\s+', ' ', line.strip())
                    parts = clean_line.split()
    
                    station_code = parts[0].strip('*')
                    
                    # Default values for the row
                    data_fields = []
                    comments = ''
    
                    # Find the index where the comments start, looking for either 'Arrived:' or 'Departed:'
                    comment_start_index = -1
                    try:
                        comment_start_index = parts.index('Departed:')
                    except ValueError:
                        try:
                            comment_start_index = parts.index('Arrived:')
                        except ValueError:
                            # If no comment is found, all parts are data fields
                            comment_start_index = len(parts)
    
                    # The data fields are everything before the comment
                    data_fields = parts[1:comment_start_index]
                    
                    # The comments are everything from the comment_start_index onwards
                    comments = ' '.join(parts[comment_start_index:])
                    
                    # If there's a '|' in the comments, replace it with a space for cleaner output
                    comments = comments.replace('|', '').strip()
    
                    # Pad data_fields to ensure a length of 6 for the time-related columns
                    # We need to handle cases where there are less than 6 fields before the comment.
                    while len(data_fields) < 6:
                        # Insert empty string for missing data, e.g., actual times.
                        data_fields.append('')
                    
                    # Construct the final row with a single comment field
                    row = [station_code] + data_fields[:6] + [comments]
                                
                    parsed_data.append(row)
        
        # Write parsed data to CSV

        output_directory = "data/csv/"
        input_file_root = os.path.splitext(input_file)[0]
        input_file_root = input_file_root.lstrip("data/extracted/")
        output_filename = os.path.join(output_directory, f"{input_file_root}.csv") 
        #print(output_filename)
        
        df = pd.DataFrame(parsed_data, columns=headers)
        df.to_csv(output_filename, index=False)
    
    except FileNotFoundError:
        print(f"Error: The file '{input_file}' was not found.")

# %% [markdown]
# ## 1. Unzip all files to extracted folders

# %%
for year in years:
    for train_num in all_trains:
        zip_path = f"./data/zips/{year}/{train_num}.zip"
        extract_to = f"./data/extracted/{year}/"
        os.makedirs(extract_to, exist_ok=True)
        try:
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                zip_ref.extractall(extract_to)
        except :
            print(f"Failed to unzip {year} train number {train_num} data.")
            continue

# %% [markdown]
# ## 2. Create output csv subfolders

# %%
for year in years:
    for train_num in all_trains:
        train_subfolder = f"./data/csv/{year}/{train_num}"
        try:
            os.makedirs(train_subfolder, exist_ok=True)
        except :
            print(f"Failed to create folder for train number {train_num}.")
            continue

# %% [markdown]
# ## 3. Parse all files

# %%
for year in years:
    print(year)
    for train_num in all_trains:
        input_dir = f"data/extracted/{year}/{train_num}"
        if os.path.exists(input_dir):
            num_files = len(os.listdir(input_dir))
            print(f"\tNum files for {year} and {train_num}: {num_files}")
            for file in os.listdir(input_dir):
                filepath = os.path.join(input_dir, file)
                try:
                    parse_train_file(filepath)
                except UnicodeDecodeError as e:
                    print(filepath)
                    continue
# Out:
# 2011
# 	Num files for 2011 and 66: 365
# 	Num files for 2011 and 67: 365
# 	Num files for 2011 and 82: 57
# 	Num files for 2011 and 86: 252
# 	Num files for 2011 and 88: 112
# 	Num files for 2011 and 93: 202
# 	Num files for 2011 and 94: 253
# 	Num files for 2011 and 95: 253
# 	Num files for 2011 and 99: 112
# 	Num files for 2011 and 132: 51
# 	Num files for 2011 and 135: 108
# 	Num files for 2011 and 137: 246
# 	Num files for 2011 and 139: 51
# 	Num files for 2011 and 150: 108
# 	Num files for 2011 and 160: 108
# 	Num files for 2011 and 161: 108
# 	Num files for 2011 and 162: 108
# 	Num files for 2011 and 163: 108
# 	Num files for 2011 and 164: 111
# 	Num files for 2011 and 165: 107
# 	Num files for 2011 and 166: 51
# 	Num files for 2011 and 167: 58
# 	Num files for 2011 and 168: 58
# 	Num files for 2011 and 169: 107
# 	Num files for 2011 and 170: 246
# 	Num files for 2011 and 171: 253
# 	Num files for 2011 and 172: 245
# 	Num files for 2011 and 173: 246
# 	Num files for 2011 and 174: 253
# 	Num files for 2011 and 175: 246
# 	Num files for 2011 and 176: 253
# 	Num files for 2011 and 177: 245
# 	Num files for 2011 and 178: 242
# 	Num files for 2011 and 190: 245
# 	Num files for 2011 and 194: 112
# 	Num files for 2011 and 195: 112
# 2012
# 	Num files for 2012 and 66: 366
# 	Num files for 2012 and 67: 366
# 	Num files for 2012 and 82: 59
# 	Num files for 2012 and 86: 253
# 	Num files for 2012 and 88: 113
# 	Num files for 2012 and 93: 201
# 	Num files for 2012 and 94: 253
# 	Num files for 2012 and 95: 253
# 	Num files for 2012 and 99: 113
# 	Num files for 2012 and 132: 55
# 	Num files for 2012 and 135: 113
# 	Num files for 2012 and 137: 253
# 	Num files for 2012 and 139: 54
# 	Num files for 2012 and 150: 113
# 	Num files for 2012 and 160: 113
# 	Num files for 2012 and 161: 113
# 	Num files for 2012 and 162: 113
# 	Num files for 2012 and 163: 113
# 	Num files for 2012 and 164: 112
# 	Num files for 2012 and 165: 113
# 	Num files for 2012 and 166: 55
# 	Num files for 2012 and 167: 58
# 	Num files for 2012 and 168: 58
# 	Num files for 2012 and 169: 112
# 	Num files for 2012 and 170: 253
# 	Num files for 2012 and 171: 253
# 	Num files for 2012 and 172: 253
# 	Num files for 2012 and 173: 253
# 	Num files for 2012 and 174: 253
# 	Num files for 2012 and 175: 252
# 	Num files for 2012 and 176: 253
# 	Num files for 2012 and 177: 253
# 	Num files for 2012 and 178: 250
# 	Num files for 2012 and 190: 253
# 	Num files for 2012 and 194: 113
# 	Num files for 2012 and 195: 113
# 2013
# 	Num files for 2013 and 66: 365
# 	Num files for 2013 and 67: 365
# 	Num files for 2013 and 82: 54
# 	Num files for 2013 and 86: 254
# 	Num files for 2013 and 88: 111
# 	Num files for 2013 and 93: 201
# 	Num files for 2013 and 94: 254
# 	Num files for 2013 and 95: 254
# 	Num files for 2013 and 99: 111
# 	Num files for 2013 and 132: 53
# 	Num files for 2013 and 135: 111
# 	Num files for 2013 and 137: 254
# 	Num files for 2013 and 139: 53
# 	Num files for 2013 and 150: 111
# 	Num files for 2013 and 160: 111
# 	Num files for 2013 and 161: 111
# 	Num files for 2013 and 162: 111
# 	Num files for 2013 and 163: 111
# 	Num files for 2013 and 164: 111
# 	Num files for 2013 and 165: 111
# 	Num files for 2013 and 166: 53
# 	Num files for 2013 and 167: 58
# 	Num files for 2013 and 168: 58
# 	Num files for 2013 and 169: 111
# 	Num files for 2013 and 170: 254
# 	Num files for 2013 and 171: 254
# 	Num files for 2013 and 172: 254
# 	Num files for 2013 and 173: 253
# 	Num files for 2013 and 174: 254
# 	Num files for 2013 and 175: 254
# 	Num files for 2013 and 176: 254
# 	Num files for 2013 and 177: 254
# 	Num files for 2013 and 178: 250
# 	Num files for 2013 and 190: 254
# 	Num files for 2013 and 194: 111
# 	Num files for 2013 and 195: 111
# 2014
# 	Num files for 2014 and 66: 366
# 	Num files for 2014 and 67: 366
# 	Num files for 2014 and 82: 53
# 	Num files for 2014 and 86: 253
# 	Num files for 2014 and 88: 113
# 	Num files for 2014 and 93: 201
# 	Num files for 2014 and 94: 253
# 	Num files for 2014 and 95: 253
# 	Num files for 2014 and 99: 113
# 	Num files for 2014 and 132: 53
# 	Num files for 2014 and 135: 113
# 	Num files for 2014 and 137: 252
# 	Num files for 2014 and 139: 53
# 	Num files for 2014 and 150: 113
# 	Num files for 2014 and 160: 111
# 	Num files for 2014 and 161: 113
# 	Num files for 2014 and 162: 113
# 	Num files for 2014 and 163: 113
# 	Num files for 2014 and 164: 113
# 	Num files for 2014 and 165: 113
# 	Num files for 2014 and 166: 53
# 	Num files for 2014 and 167: 60
# 	Num files for 2014 and 168: 61
# 	Num files for 2014 and 169: 113
# 	Num files for 2014 and 170: 253
# 	Num files for 2014 and 171: 253
# 	Num files for 2014 and 172: 253
# 	Num files for 2014 and 173: 253
# 	Num files for 2014 and 174: 253
# 	Num files for 2014 and 175: 253
# 	Num files for 2014 and 176: 253
# 	Num files for 2014 and 177: 253
# 	Num files for 2014 and 178: 253
# 	Num files for 2014 and 190: 253
# 	Num files for 2014 and 194: 113
# 	Num files for 2014 and 195: 113
# 2015
# 	Num files for 2015 and 66: 366
# 	Num files for 2015 and 67: 258
# 	Num files for 2015 and 82: 55
# 	Num files for 2015 and 86: 254
# 	Num files for 2015 and 88: 113
# 	Num files for 2015 and 93: 202
# 	Num files for 2015 and 94: 254
# 	Num files for 2015 and 95: 254
# 	Num files for 2015 and 99: 113
# 	Num files for 2015 and 132: 54
# 	Num files for 2015 and 135: 113
# 	Num files for 2015 and 137: 254
# 	Num files for 2015 and 139: 54
# 	Num files for 2015 and 150: 113
# 	Num files for 2015 and 160: 113
# 	Num files for 2015 and 161: 113
# 	Num files for 2015 and 162: 113
# 	Num files for 2015 and 163: 113
# 	Num files for 2015 and 164: 113
# 	Num files for 2015 and 165: 113
# 	Num files for 2015 and 166: 54
# 	Num files for 2015 and 167: 60
# 	Num files for 2015 and 168: 60
# 	Num files for 2015 and 169: 113
# 	Num files for 2015 and 170: 254
# 	Num files for 2015 and 171: 254
# 	Num files for 2015 and 172: 254
# 	Num files for 2015 and 173: 254
# 	Num files for 2015 and 174: 253
# 	Num files for 2015 and 175: 254
# 	Num files for 2015 and 176: 254
# 	Num files for 2015 and 177: 254
# 	Num files for 2015 and 178: 254
# 	Num files for 2015 and 190: 254
# 	Num files for 2015 and 194: 92
# 	Num files for 2015 and 195: 113
# 2016
# 	Num files for 2016 and 66: 367
# 	Num files for 2016 and 67: 254
# 	Num files for 2016 and 82: 59
# 	Num files for 2016 and 86: 254
# 	Num files for 2016 and 88: 114
# 	Num files for 2016 and 93: 203
# 	Num files for 2016 and 94: 254
# 	Num files for 2016 and 95: 254
# 	Num files for 2016 and 99: 114
# 	Num files for 2016 and 132: 54
# 	Num files for 2016 and 135: 114
# 	Num files for 2016 and 137: 254
# 	Num files for 2016 and 139: 54
# 	Num files for 2016 and 150: 114
# 	Num files for 2016 and 160: 114
# 	Num files for 2016 and 161: 114
# 	Num files for 2016 and 162: 114
# 	Num files for 2016 and 163: 114
# 	Num files for 2016 and 164: 114
# 	Num files for 2016 and 165: 114
# 	Num files for 2016 and 166: 54
# 	Num files for 2016 and 167: 61
# 	Num files for 2016 and 168: 61
# 	Num files for 2016 and 169: 115
# 	Num files for 2016 and 170: 254
# 	Num files for 2016 and 171: 254
# 	Num files for 2016 and 172: 254
# 	Num files for 2016 and 173: 254
# 	Num files for 2016 and 174: 253
# 	Num files for 2016 and 175: 254
# 	Num files for 2016 and 176: 254
# 	Num files for 2016 and 177: 254
# 	Num files for 2016 and 178: 254
# 	Num files for 2016 and 190: 254
# 	Num files for 2016 and 194: 53
# 	Num files for 2016 and 195: 114
# 2017
# 	Num files for 2017 and 66: 366
# 	Num files for 2017 and 67: 253
# 	Num files for 2017 and 82: 59
# 	Num files for 2017 and 86: 253
# 	Num files for 2017 and 88: 114
# 	Num files for 2017 and 93: 201
# 	Num files for 2017 and 94: 253
# 	Num files for 2017 and 95: 253
# 	Num files for 2017 and 99: 114
# 	Num files for 2017 and 132: 54
# 	Num files for 2017 and 135: 114
# 	Num files for 2017 and 137: 253
# 	Num files for 2017 and 139: 54
# 	Num files for 2017 and 150: 114
# 	Num files for 2017 and 160: 114
# 	Num files for 2017 and 161: 114
# 	Num files for 2017 and 162: 114
# 	Num files for 2017 and 163: 75
# 	Num files for 2017 and 164: 114
# 	Num files for 2017 and 165: 114
# 	Num files for 2017 and 166: 54
# 	Num files for 2017 and 167: 61
# 	Num files for 2017 and 168: 61
# 	Num files for 2017 and 169: 115
# 	Num files for 2017 and 170: 253
# 	Num files for 2017 and 171: 253
# 	Num files for 2017 and 172: 253
# 	Num files for 2017 and 173: 253
# 	Num files for 2017 and 174: 253
# 	Num files for 2017 and 175: 253
# 	Num files for 2017 and 176: 253
# 	Num files for 2017 and 177: 253
# 	Num files for 2017 and 178: 253
# 	Num files for 2017 and 190: 253
# 	Num files for 2017 and 194: 59
# 	Num files for 2017 and 195: 114
# 2018
# 	Num files for 2018 and 66: 366
# 	Num files for 2018 and 67: 254
# 	Num files for 2018 and 82: 61
# 	Num files for 2018 and 86: 253
# 	Num files for 2018 and 88: 114
# 	Num files for 2018 and 93: 201
# 	Num files for 2018 and 94: 253
# 	Num files for 2018 and 95: 253
# 	Num files for 2018 and 99: 114
# 	Num files for 2018 and 132: 55
# 	Num files for 2018 and 135: 114
# 	Num files for 2018 and 137: 252
# 	Num files for 2018 and 139: 55
# 	Num files for 2018 and 150: 114
# 	Num files for 2018 and 160: 114
# 	Num files for 2018 and 161: 114
# 	Num files for 2018 and 162: 114
# 	Num files for 2018 and 163: 61
# 	Num files for 2018 and 164: 114
# 	Num files for 2018 and 165: 114
# 	Num files for 2018 and 166: 55
# 	Num files for 2018 and 167: 62
# 	Num files for 2018 and 168: 61
# 	Num files for 2018 and 169: 115
# 	Num files for 2018 and 170: 253
# 	Num files for 2018 and 171: 253
# 	Num files for 2018 and 172: 254
# 	Num files for 2018 and 173: 253
# 	Num files for 2018 and 174: 253
# 	Num files for 2018 and 175: 253
# 	Num files for 2018 and 176: 253
# 	Num files for 2018 and 177: 252
# 	Num files for 2018 and 178: 253
# 	Num files for 2018 and 190: 253
# 	Num files for 2018 and 194: 61
# 	Num files for 2018 and 195: 114
# 2019
# 	Num files for 2019 and 66: 366
# 	Num files for 2019 and 67: 254
# 	Num files for 2019 and 82: 61
# 	Num files for 2019 and 86: 251
# 	Num files for 2019 and 88: 116
# 	Num files for 2019 and 93: 242
# 	Num files for 2019 and 94: 251
# 	Num files for 2019 and 95: 251
# 	Num files for 2019 and 99: 116
# 	Num files for 2019 and 132: 56
# 	Num files for 2019 and 135: 116
# 	Num files for 2019 and 137: 251
# 	Num files for 2019 and 139: 56
# 	Num files for 2019 and 150: 116
# 	Num files for 2019 and 160: 116
# 	Num files for 2019 and 161: 116
# 	Num files for 2019 and 162: 116
# 	Num files for 2019 and 163: 61
# 	Num files for 2019 and 164: 116
# 	Num files for 2019 and 165: 116
# 	Num files for 2019 and 166: 55
# 	Num files for 2019 and 167: 61
# 	Num files for 2019 and 168: 59
# 	Num files for 2019 and 169: 115
# 	Num files for 2019 and 170: 251
# 	Num files for 2019 and 171: 251
# 	Num files for 2019 and 172: 251
# 	Num files for 2019 and 173: 251
# 	Num files for 2019 and 174: 251
# 	Num files for 2019 and 175: 251
# 	Num files for 2019 and 176: 251
# 	Num files for 2019 and 177: 251
# 	Num files for 2019 and 178: 251
# 	Num files for 2019 and 190: 251
# 	Num files for 2019 and 194: 62
# 	Num files for 2019 and 195: 116
# 2020
# 	Num files for 2020 and 66: 198
# 	Num files for 2020 and 67: 133
# 	Num files for 2020 and 82: 59
# 	Num files for 2020 and 86: 52
# 	Num files for 2020 and 88: 125
# 	Num files for 2020 and 93: 130
# 	Num files for 2020 and 94: 243
# 	Num files for 2020 and 95: 243
# 	Num files for 2020 and 99: 125
# 	Num files for 2020 and 132: 13
# 	Num files for 2020 and 135: 111
# 	Num files for 2020 and 137: 155
# 	Num files for 2020 and 139: 38
# 	Num files for 2020 and 150: 72
# 	Num files for 2020 and 160: 78
# 	Num files for 2020 and 161: 72
# 	Num files for 2020 and 162: 56
# 	Num files for 2020 and 163: 54
# 	Num files for 2020 and 164: 99
# 	Num files for 2020 and 165: 82
# 	Num files for 2020 and 166: 52
# 	Num files for 2020 and 167: 48
# 	Num files for 2020 and 168: 74
# 	Num files for 2020 and 169: 79
# 	Num files for 2020 and 170: 199
# 	Num files for 2020 and 171: 243
# 	Num files for 2020 and 172: 130
# 	Num files for 2020 and 173: 243
# 	Num files for 2020 and 174: 243
# 	Num files for 2020 and 175: 199
# 	Num files for 2020 and 176: 243
# 	Num files for 2020 and 177: 51
# 	Num files for 2020 and 178: 155
# 	Num files for 2020 and 190: 243
# 	Num files for 2020 and 194: 74
# 	Num files for 2020 and 195: 109
# 2021
# 	Num files for 2021 and 66: 366
# data/extracted/2021/66/.DS_Store
# 	Num files for 2021 and 67: 256
# 	Num files for 2021 and 82: 59
# 	Num files for 2021 and 86: 120
# 	Num files for 2021 and 88: 111
# 	Num files for 2021 and 93: 256
# 	Num files for 2021 and 94: 256
# 	Num files for 2021 and 95: 256
# 	Num files for 2021 and 99: 111
# 	Num files for 2021 and 132: 24
# 	Num files for 2021 and 135: 111
# 	Num files for 2021 and 137: 256
# 	Num files for 2021 and 139: 53
# 	Num files for 2021 and 150: 82
# 	Num files for 2021 and 160: 53
# 	Num files for 2021 and 161: 82
# 	Num files for 2021 and 162: 77
# 	Num files for 2021 and 163: 25
# 	Num files for 2021 and 164: 111
# 	Num files for 2021 and 165: 53
# 	Num files for 2021 and 166: 53
# 	Num files for 2021 and 167: 59
# 	Num files for 2021 and 168: 59
# 	Num files for 2021 and 169: 77
# 	Num files for 2021 and 170: 256
# 	Num files for 2021 and 171: 256
# 	Num files for 2021 and 172: 256
# 	Num files for 2021 and 173: 256
# 	Num files for 2021 and 174: 256
# 	Num files for 2021 and 175: 255
# 	Num files for 2021 and 176: 256
# 	Num files for 2021 and 177: 193
# 	Num files for 2021 and 178: 256
# 	Num files for 2021 and 190: 255
# 	Num files for 2021 and 194: 59
# 	Num files for 2021 and 195: 111
# 2022
# 	Num files for 2022 and 66: 191
# 	Num files for 2022 and 67: 131
# 	Num files for 2022 and 82: 59
# 	Num files for 2022 and 86: 253
# 	Num files for 2022 and 88: 112
# 	Num files for 2022 and 93: 253
# 	Num files for 2022 and 94: 253
# 	Num files for 2022 and 95: 253
# 	Num files for 2022 and 99: 112
# 	Num files for 2022 and 132: 52
# 	Num files for 2022 and 135: 112
# 	Num files for 2022 and 137: 253
# 	Num files for 2022 and 139: 53
# 	Num files for 2022 and 150: 112
# 	Num files for 2022 and 160: 52
# 	Num files for 2022 and 161: 112
# 	Num files for 2022 and 162: 110
# 	Num files for 2022 and 163: 60
# 	Num files for 2022 and 164: 112
# 	Num files for 2022 and 165: 52
# 	Num files for 2022 and 166: 52
# 	Num files for 2022 and 167: 60
# 	Num files for 2022 and 168: 60
# 	Num files for 2022 and 169: 112
# 	Num files for 2022 and 170: 14
# 	Num files for 2022 and 171: 253
# 	Num files for 2022 and 172: 253
# 	Num files for 2022 and 173: 253
# 	Num files for 2022 and 174: 253
# 	Num files for 2022 and 175: 253
# 	Num files for 2022 and 176: 253
# 	Num files for 2022 and 177: 78
# 	Num files for 2022 and 178: 253
# 	Num files for 2022 and 190: 253
# 	Num files for 2022 and 194: 60
# 	Num files for 2022 and 195: 111
# 2023
# 	Num files for 2023 and 66: 365
# 	Num files for 2023 and 67: 256
# 	Num files for 2023 and 82: 58
# 	Num files for 2023 and 86: 252
# 	Num files for 2023 and 88: 113
# 	Num files for 2023 and 93: 252
# 	Num files for 2023 and 94: 252
# 	Num files for 2023 and 95: 252
# 	Num files for 2023 and 99: 113
# 	Num files for 2023 and 132: 54
# 	Num files for 2023 and 135: 113
# 	Num files for 2023 and 137: 252
# 	Num files for 2023 and 139: 54
# 	Num files for 2023 and 150: 113
# 	Num files for 2023 and 160: 98
# 	Num files for 2023 and 161: 113
# 	Num files for 2023 and 162: 112
# 	Num files for 2023 and 163: 59
# 	Num files for 2023 and 164: 113
# 	Num files for 2023 and 165: 98
# 	Num files for 2023 and 166: 54
# 	Num files for 2023 and 167: 59
# 	Num files for 2023 and 168: 60
# 	Num files for 2023 and 169: 112
# 	Num files for 2023 and 170: 190
# 	Num files for 2023 and 171: 252
# 	Num files for 2023 and 172: 252
# 	Num files for 2023 and 173: 252
# 	Num files for 2023 and 174: 252
# 	Num files for 2023 and 175: 252
# 	Num files for 2023 and 176: 252
# 	Num files for 2023 and 177: 190
# 	Num files for 2023 and 178: 252
# 	Num files for 2023 and 190: 207
# 	Num files for 2023 and 194: 59
# 	Num files for 2023 and 195: 113
# 2024
# 	Num files for 2024 and 66: 366
# 	Num files for 2024 and 67: 252
# 	Num files for 2024 and 82: 60
# 	Num files for 2024 and 86: 253
# 	Num files for 2024 and 88: 113
# 	Num files for 2024 and 93: 253
# 	Num files for 2024 and 94: 253
# 	Num files for 2024 and 95: 253
# 	Num files for 2024 and 99: 113
# 	Num files for 2024 and 132: 54
# 	Num files for 2024 and 135: 113
# 	Num files for 2024 and 137: 253
# 	Num files for 2024 and 139: 45
# 	Num files for 2024 and 150: 113
# 	Num files for 2024 and 160: 113
# 	Num files for 2024 and 161: 113
# 	Num files for 2024 and 162: 113
# 	Num files for 2024 and 163: 59
# 	Num files for 2024 and 164: 113
# 	Num files for 2024 and 165: 113
# 	Num files for 2024 and 166: 54
# 	Num files for 2024 and 167: 68
# 	Num files for 2024 and 168: 59
# 	Num files for 2024 and 169: 86
# 	Num files for 2024 and 170: 253
# 	Num files for 2024 and 171: 253
# 	Num files for 2024 and 172: 253
# 	Num files for 2024 and 173: 253
# 	Num files for 2024 and 174: 253
# 	Num files for 2024 and 175: 253
# 	Num files for 2024 and 176: 253
# 	Num files for 2024 and 177: 253
# 	Num files for 2024 and 178: 253
# 	Num files for 2024 and 190: 253
# 	Num files for 2024 and 194: 59
# 	Num files for 2024 and 195: 113
